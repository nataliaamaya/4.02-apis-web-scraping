# %% [markdown]
# ## Learning Objectives
#
# By the end of this module, you'll be able to:
#
# * Retrieve structured data from APIs using the Requests library
# * Authenticate API requests and handle common response formats
# * Extract and parse HTML content using BeautifulSoup
# * Store raw data for later analysis in reproducible project structures
# * Apply ethical and legal best practices when collecting web data

# %%
# imports

# %% [markdown]
# ---
#
# ## 1. API Example (No API Key Required)
#
# We're going to get posts from the following [website](https://jsonplaceholder.typicode.com/)
#
# It is a commonly used example website when you're learning about API's and webscraping.

# %%
# API Endpoint

# %% [markdown]
# We're going to use the [requests](https://pypi.org/project/requests/) library to connect to a website.
#
# A `GET` request is an HTTP method to *get* data from a web server.

# %%
# store our get request as a variable

# %% [markdown]
# You've likely gone to an incorrect url and gotten a `404` Error
#
# [Here is a list of the status codes](https://developer.mozilla.org/en-US/docs/Web/HTTP/Reference/Status#client_error_responses)

# %%
# Check the status code of our response, you should get 200

# %% [markdown]
# Success, we have 200!

# %%
# so what is our response?

print(type(response))

# %%
response

# %%
# .json() returns the json-encoded content of a response

# %%
# What do we like to use instead of lists/dictionaries? DataFrames!
# convert it to a dataframe

# %%
df.head()

# %% [markdown]
# ---
#
# ## 2. API Authentication + Pagination (Concept Demo)
#
# JSONPlaceholder doesn’t paginate, so we simulate a real-world pattern using query params.

# %%
# set up our base url

# %%
# set up an empty list


# Simulate pagination wiht query parameters

# convert to a dataframe


# inspect first few rows

# %% [markdown]
# ---
#
# ## 3. Web Scraping Example (Simple + Reliable)
#
# Use [Books to Scrape](https://books.toscrape.com/) — intentionally built for scraping.
#
# ---
#
# ### BeautifulSoup()
#
# [BeautifulSoup](https://beautiful-soup-4.readthedocs.io/en/latest/) is a Python library for parsing HTML and XML content from websites. There are many instances where the data you want from a website does not have an API for you to get data from. If you're able to, you can scrape the website to get its content.
#
# **IMPORTANT NOTE**: Make sure you're allowed to scrape a website being scraping it!

# %%
# uncomment and install if you haven't
# !pip install beautifulsoup4

# %%
# import beautiful soup

# %%
# set up our base url and connect to it

# %% [markdown]
# Let's look at the `.text` of our `response`
#
# ---

# %% [markdown]
# Notice the `<!DOCTYPE html>` indicating that this HTML.
#
# HTML (HyperText Markup Language) is the standard markup language to structure web content.
#
# [HTML Cheatsheet](https://developer.mozilla.org/en-US/docs/Web/HTML/Guides/Cheatsheet)
#
# You don't need to know how to write HTML, only to find which content you want in the HTML hierarchy.
#
# ---
#
# Let's see how Beautiful Soup can parse out the HTML.

# %%
# create a "soup" object

# %%
# soup

# %% [markdown]
# Inside our soup object, we can use the `.find_all()` method to look for certain sections of our HTML.

# %% [markdown]
# You'll notice in the `<h3>` tag, it has the title of the book. We can loop through each of our articles, extract that tag, and put it in a dictionary, append to a list, and convert to a dataframe.

# %%
# Convert to a dataframe

# %% [markdown]
# We took a bunch of unstructured data in HTML and then cleaned it up to store in a nicely structure dataframe! This is a very common task for anyone handling data!

# %%
# import pathlib

# %%
# Export your dataframe as a .csv file to your processed data folder.

# %% [markdown]
# It's a good practice to store your scraped, raw data. We'll use the `with` syntax for this and the json library.

# %%
# import json
